# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\mshre\OneDrive\Desktop\Zirconia\cubic_zirconia.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# ...

# %%
col_headings = {'Unnamed: 0':'slno'}

# %%
df.rename(columns=col_headings, inplace=True)

# %%
df
# Out:
#         slno  carat        cut color clarity  depth  table     x     y     z  \
# 0          1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1          2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2          3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3          4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4          5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 26962  26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963  26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964  26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965  26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966  26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
#        price
# 0        499
# 1        984
# ...

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.nunique()
# Out:
# carat       257
# cut           5
# color         7
# clarity       8
# depth       169
# table       112
# x           531
# y           526
# z           356
# price      8742
# dtype: int64

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 
df['cut']= label_encoder.fit_transform(df['cut'])
df['color']= label_encoder.fit_transform(df['color'])
df['clarity']= label_encoder.fit_transform(df['clarity'])


print(df['cut'].unique())
print(df['color'].unique())
print(df['clarity'].unique())
# Out:
# [2 3 4 1 0]
# [1 3 2 0 4 6 5]
# [2 1 7 4 6 5 3 0]

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  int32
#  2   color    26967 non-null  int32
#  3   clarity  26967 non-null  int32
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int32(3), int64(1)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  26967.000000  26967.000000  26967.000000  26967.000000  26270.000000
# mean       0.798375      2.554604      2.606111      3.833537     61.745147
# std        0.477745      1.024243      1.705992      1.724904      1.412860
# min        0.200000      0.000000      0.000000      0.000000     50.800000
# 25%        0.400000      2.000000      1.000000      2.000000     61.000000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.050000      3.000000      4.000000      5.000000     62.500000
# max        4.500000      4.000000      6.000000      7.000000     73.600000
#
#               table             x             y             z         price
# count  26967.000000  26967.000000  26967.000000  26967.000000  26967.000000
# mean      57.456080      5.729854      5.733569      3.538057   3939.518115
# ...

# %%
df.isna().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
df.index = df.index+1

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
#Case1: removing coumns with NAN values

df1 = df.dropna(axis=1)

# %%
df1
# Out:
#        carat  cut  color  clarity  table     x     y     z  price
# 1       0.30    2      1        2   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 9 columns]

# %%
x = df1.iloc[:,:-1]
y = df1.iloc[:,-1:]
print(x)
print(y)
# Out:
#        carat  cut  color  clarity  table     x     y     z
# 1       0.30    2      1        2   58.0  4.27  4.29  2.66
# 2       0.33    3      3        1   58.0  4.42  4.46  2.70
# 3       0.90    4      1        7   60.0  6.04  6.12  3.78
# 4       0.42    2      2        4   56.0  4.82  4.80  2.96
# 5       0.31    2      2        6   59.0  4.35  4.43  2.65
# ...      ...  ...    ...      ...    ...   ...   ...   ...
# 26963   1.11    3      3        2   58.0  6.61  6.52  4.09
# 26964   0.33    2      4        1   55.0  4.44  4.42  2.74
# 26965   0.51    3      1        5   58.0  5.12  5.15  3.17
# 26966   0.27    4      2        7   56.0  4.19  4.20  2.60
# 26967   1.25    3      6        2   58.0  6.90  6.88  4.27
#
# [26967 rows x 8 columns]
#        price
# 1        499
# 2        984
# 3       6289
# 4       1082
# 5        779
# ...      ...
# 26963   5408
# 26964   1114
# 26965   1656
# 26966    682
# 26967   5166
#
# [26967 rows x 1 columns]

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
print(x_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# table      0
# x          0
# y          0
# z          0
# dtype: int64
# price    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
# Create and train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict y for the new data
y_pred = model.predict(x_test)

print("Predicted y:", y_pred)
# Out:
# Predicted y: [[1890.06677929]
#  [9832.84471159]
#  [2451.69774773]
#  ...
#  [ 898.04443154]
#  [ 884.75159746]
#  [4008.74443171]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# R-squared (R²)
r_squared = r2_score(y_test, y_pred)

print(f'MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R²: {r_squared}')
# Out:
# MSE: 1994359.2178777047, RMSE: 1412.2178365527411, MAE: 884.4918037905749, R²: 0.8802787707990937

# %%
#Case2: removing rows with NAN values

df2 = df[df['depth'].notna()]

# %%
df2
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26270 rows x 10 columns]

# %%
x2 = df2.iloc[:,:-1]
y2 = df2.iloc[:,-1:]

# %%
print(x2.isnull().sum())
#print(y2.isnull().sum())
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
x_train, x_test,y_train,y_test = train_test_split(x2,y2,test_size=0.3)
model = LinearRegression()
model.fit(x_train, y_train)

# Predict y for the new data
y_pred = model.predict(x_test)

print("Predicted y:", y_pred)
# Out:
# Predicted y: [[-468.24768455]
#  [-587.20498866]
#  [-194.6960407 ]
#  ...
#  [ 133.18452358]
#  [5768.35423819]
#  [1122.4184537 ]]

# %%
# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# R-squared (R²)
r_squared = r2_score(y_test, y_pred)

print(f'MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R²: {r_squared}')
# Out:
# MSE: 1819656.8475609338, RMSE: 1348.9465695723213, MAE: 867.595267723209, R²: 0.8873331536196747

# %%
#Case3: Replacing NAN values with median

df3 = df
df3['depth'] = df3['depth'].fillna(df3['depth'].mean)

# %%
x3 = df3.iloc[:,:-1]
y3 = df3.iloc[:,-1:]

# %%
type(y3)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train, x_test,y_train,y_test = train_test_split(x3,y3,test_size=0.3)

x_train
# Out:
#        carat  cut  color  clarity depth  table     x     y     z
# 24969   1.06    2      3        5  62.2   56.0  6.51  6.54  4.06
# 10080   0.52    2      0        2  60.9   57.0  5.17  5.21  3.16
# 18356   0.70    3      0        5  60.9   57.0  5.71  5.69  3.47
# 2421    1.00    3      2        3  61.5   60.0  6.35  6.33  3.90
# 7126    1.50    4      6        7  63.3   56.0  7.18  7.29  4.58
# ...      ...  ...    ...      ...   ...    ...   ...   ...   ...
# 23048   1.02    2      2        7  61.1   56.3  6.48  6.52  3.97
# 14854   0.27    4      1        5  63.0   57.0  4.12  4.16  2.61
# 14037   0.51    4      0        7  63.1   58.0  5.10  5.07  3.21
# 23571   1.61    3      4        2  60.8   56.0  7.61  7.58  4.62
# 10275   1.50    4      0        4  61.2   63.0  7.28  7.32  4.47
#
# [18876 rows x 9 columns]

# %%
y_train
# Out:
#        price
# 14333  15528
# 16570    439
# 17098   8341
# 16373   1050
# 20233   2657
# ...      ...
# 530     4974
# 21981   2870
# 20776   1429
# 2625    1316
# 1926     517
#
# [18876 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 2>()
#       1 model = LinearRegression()
# ----> 2 model.fit(x_train, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...

# %%
# Predict y for the new data
y_pred = model.predict(x_test)

print("Predicted y:", y_pred)

# %%
# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# R-squared (R²)
r_squared = r2_score(y_test, y_pred)

print(f'MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R²: {r_squared}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [104], in <cell line: 2>()
#       1 # Mean Squared Error (MSE)
# ----> 2 mse = mean_squared_error(y_test, y_pred)
#       4 # Root Mean Squared Error (RMSE)
#       5 rmse = np.sqrt(mse)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
# ...

# %%
#Case4: Replacing NAN values with mean

df4 = df
df4['depth'] = df4['depth'].fillna(df4['depth'].mean)

# %%
x4 = df4.iloc[:,:-1]
y4 = df4.iloc[:,-1:]

# %%
print(x4.dtypes)
print(y4.dtypes)
# Out:
# carat      float64
# cut          int64
# color        int64
# clarity      int64
# depth       object
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object
# price    int64
# dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x4, y4,test_size=0.3)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 3>()
#       1 x_train, x_test, y_train, y_test = train_test_split(x4, y4,test_size=0.3)
#       2 model = LinearRegression()
# ----> 3 model.fit(x_train, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# Predict y for the new data
y_pred = model.predict(x_test)

print("Predicted y:", y_pred)

# %%
# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# R-squared (R²)
r_squared = r2_score(y_test, y_pred)

print(f'MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R²: {r_squared}')
# Out:
# MSE: 1804977.0868239386, RMSE: 1343.494356826235, MAE: 857.9498585159477, R²: 0.8861818031842326

# %% [markdown]
# #Univariate analysis

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
import seaborn as sns
#histogram
sns.distplot(df['carat'])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
sns.distplot(df['table'])
# Out:
# <AxesSubplot:xlabel='table', ylabel='Density'>

# %%
sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['x'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='Density'>

# %%
sns.distplot(df['y'])
# Out:
# <AxesSubplot:xlabel='y', ylabel='Density'>

# %%
sns.distplot(df['z'])
# Out:
# <AxesSubplot:xlabel='z', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())
# Out:
# Skewness: 1.618550
# Kurtosis: 2.148617

# %%
#standardizing data
#mean=0, standard deviation=1

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Assuming df is your DataFrame and 'x' is the column you want to scale
i = 'x'  # Replace 'x' with the actual column name

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit and transform the entire 'x' column
df[i + '_scaled'] = scaler.fit_transform(df[[i]])

# If you want to overwrite the original column with the scaled values
# df[i] = scaler.fit_transform(df[[i]])

# %% [markdown]
# #bivariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(13, 17))
sns.pairplot(data=df.drop(['cut', 'color', 'clarity'], axis=1))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#df is the DataFrame with columns 'cut' and 'price'
sns.barplot(x='cut', y='price', data=df)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='cut', y='price', data=df, ci=None)  # ci=None to disable error bars
sns.swarmplot(x='cut', y='price', data=df, color='black', size=3)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='clarity', y='price', data=df, ci=None)  # ci=None to disable error bars
sns.swarmplot(x='clarity', y='price', data=df, color='black', size=3)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='color', y='price', data=df, ci=None)  # ci=None to disable error bars
sns.swarmplot(x='color', y='price', data=df, color='black', size=3)
plt.show()

# %%
# Assuming 'df' is your DataFrame
grouped_data = df.groupby('color')['price'].mean().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
grouped_data.plot.bar(fontsize=12)
plt.title("Color Vs Price", fontsize=18)
plt.xlabel("Color", fontsize=14)
plt.ylabel("Price", fontsize=14)
plt.show()

# %% [markdown]
# #Multivariate analysis

# %%
cor = df.corr()
cor
# Out:
#             carat       cut     color   clarity     depth     table         x  \
# carat    1.000000  0.020146  0.293966 -0.211670  0.035364  0.181685  0.976368
# cut      0.020146  1.000000 -0.000679  0.017603 -0.186925  0.143989  0.024919
# color    0.293966 -0.000679  1.000000 -0.023366  0.050992  0.024418  0.274076
# clarity -0.211670  0.017603 -0.023366  1.000000 -0.053245 -0.079601 -0.224428
# depth    0.035364 -0.186925  0.050992 -0.053245  1.000000 -0.298011 -0.018715
# table    0.181685  0.143989  0.024418 -0.079601 -0.298011  1.000000  0.196206
# x        0.976368  0.024919  0.274076 -0.224428 -0.018715  0.196206  1.000000
# y        0.941071  0.029999  0.264290 -0.213497 -0.024735  0.182346  0.962715
# z        0.940640  0.006795  0.267356 -0.219203  0.101624  0.148944  0.956606
# price    0.922416  0.039287  0.173213 -0.069447 -0.002569  0.126942  0.886247
#
#                 y         z     price
# carat    0.941071  0.940640  0.922416
# ...

# %%
cor = df.corr()
plt.figure(figsize=(12, 7))
sns.heatmap(cor, annot=True, vmin=-1, vmax=1)
plt.show()

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
# Check for duplicate data

dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

df[dups]
# Out:
# Number of duplicate rows = 34
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 4757    0.35    3      6        4   62.4   58.0  5.67  5.64  3.53    949
# 6216    0.71    1      2        3   64.1   60.0  0.00  0.00  0.00   2130
# 8145    0.33    2      3        4   62.1   55.0  4.46  4.43  2.76    854
# 8920    1.52    1      1        0   57.3   58.0  7.53  7.42  4.28   3105
# 9819    0.35    2      2        5   61.4   54.0  4.58  4.54  2.80    906
# 10474   0.79    2      3        2   62.3   57.0  5.90  5.85  3.66   2898
# 10501   1.00    3      2        7   60.6   54.0  6.56  6.52  3.96   8924
# 12895   1.21    3      0        3   62.5   57.0  6.79  6.71  4.22   6505
# 13548   0.43    2      3        4   61.9   55.0  4.84  4.86  3.00    943
# 13784   0.79    2      3        2   62.3   57.0  5.90  5.85  3.66   2898
# 14390   0.60    3      0        3   62.0   57.0  5.43  5.35  3.34   1196
# ...

# %%
df['depth'].isna().sum()
# Out:
# 697

# %%
df1 = df
df1['depth'] = df['depth'].fillna(np.mean(df['depth']))

# %%
df1
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# Split x and y into training and test set in 75:25 ratio
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20 , random_state=1)

# %%
# invoke the LinearRegression function and find the bestfit model on training data

regression_model = LinearRegression()
regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Let us explore the coefficients for each of the independent attributes

for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 11023.920955358983
# The coefficient for cut is 62.267092303639515
# The coefficient for color is -273.89864737825206
# The coefficient for clarity is 293.07838557771385
# The coefficient for depth is -153.60225107050871
# The coefficient for table is -95.80722713080608
# The coefficient for x is -1139.3186890830182
# The coefficient for y is 9.01821846050666
# The coefficient for z is -35.84497888948151

# %%
# R square on training data
regression_model.score(x_train, y_train)
# Out:
# 0.8872314078578574

# %%
# Predict y for the new data
y_pred = model.predict(x_test)

print("Predicted y:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [266], in <cell line: 2>()
#       1 # Predict y for the new data
# ----> 2 y_pred = model.predict(x_test)
#       4 print("Predicted y:", y_pred)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:346, in LinearModel._decision_function(self, X)
#     343 check_is_fitted(self)
#     345 X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 346 return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
df1 = df

# %%
df_sum = df1.describe()
df_sum.loc['max']

# %%
# New row
new_row = ['name', 1, 2, 3, 4, 5, 6, 6]

# Add the new row with an integer index
df_sum.loc[len(df_sum.index)] = new_row

# %%
# Rename the index of the last added row to 'new_name'
new_name = 'new_name'
df_sum.index = df_sum.index[:-1].tolist() + [new_name]

# %%
df_sum
