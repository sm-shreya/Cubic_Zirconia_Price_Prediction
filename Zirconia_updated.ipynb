# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\mshre\OneDrive\Desktop\data\Zirconia\cubic_zirconia.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# ...

# %%
df = df.iloc[:,1:]
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
df.bkp = df.copy()

# %%
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26967.000000  26270.000000  26967.000000  26967.000000  26967.000000
# mean       0.798375     61.745147     57.456080      5.729854      5.733569
# std        0.477745      1.412860      2.232068      1.128516      1.166058
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.710000
# 50%        0.700000     61.800000     57.000000      5.690000      5.710000
# 75%        1.050000     62.500000     59.000000      6.550000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26967.000000  26967.000000
# mean       3.538057   3939.518115
# std        0.720624   4024.864666
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2375.000000
# 75%        4.040000   5360.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  object
#  2   color    26967 non-null  object
#  3   clarity  26967 non-null  object
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
num_cols = []
for i in (df.columns):
    if df[i].dtype != object:
        num_cols.append(i)

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df[(df.x==0)|(df.y==0)|(df.z==0)]
# Out:
#        carat      cut color clarity  depth  table     x     y    z  price
# 5821    0.71     Good     F     SI2   64.1   60.0  0.00  0.00  0.0   2130
# 6034    2.02  Premium     H     VS2   62.7   53.0  8.02  7.95  0.0  18207
# 6215    0.71     Good     F     SI2   64.1   60.0  0.00  0.00  0.0   2130
# 10827   2.20  Premium     H     SI1   61.2   59.0  8.42  8.37  0.0  17265
# 12498   2.18  Premium     H     SI2   59.4   61.0  8.49  8.45  0.0  12631
# 12689   1.10  Premium     G     SI2   63.0   59.0  6.50  6.47  0.0   3696
# 17506   1.14     Fair     G     VS1   57.5   67.0  0.00  0.00  0.0   6381
# 18194   1.01  Premium     H      I1   58.1   59.0  6.66  6.60  0.0   3167
# 23758   1.12  Premium     G      I1   60.4   59.0  6.71  6.67  0.0   2383

# %%
df = df.drop(df[(df['x'] == 0) | (df['y'] == 0) | (df['z'] == 0)].index)
print(df.shape)
df
# Out:
# (26958, 10)
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26958 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
df[['depth']] = df[['depth']].fillna(df[['depth']].median())

# %%
df['depth'].median()
# Out:
# 61.8

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
num_cols
# Out:
# ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
def calc_rows(total_plots, plots_in_a_row):
    return int(np.ceil(total_plots / plots_in_a_row))

plots_in_a_row = 3
rows = calc_rows(len(num_cols), plots_in_a_row)

# Create subplots
fig, axes = plt.subplots(rows, plots_in_a_row, figsize=(20, 20))
fig.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots

# Flatten the axes array to simplify indexing
axes = axes.flatten()

for i, ax in enumerate(axes[:len(num_cols)]):
    plot_title = "Plot of " + num_cols[i]
    sns.histplot(x=df[num_cols[i]], color='green', ax=ax)
    ax.set(title=plot_title)

# Hide empty subplots (if any)
for ax in axes[len(num_cols):]:
    ax.axis('off')

plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(rows, plots_in_a_row, figsize=(20, 20))
fig.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots
for i, col in enumerate(num_cols):
    plt.subplot(rows, plots_in_a_row,i+1)
    box_plot_title = "box plot of " + num_cols[i]
    sns.boxplot(x= col, data =df, color='green').set(title = box_plot_title)
    
plt.show()

# %%
plt.subplots(figsize=(20,20))
for i, col in enumerate(num_cols):
  plt.subplot(rows, plots_in_a_row,i+1)
  sns.distplot(df[col])
plt.show()

# %%
cat_cols = df.columns[df.dtypes == object]

# %%
#no. of values of each quality
for i, col in enumerate(cat_cols):
    sns.catplot(x=col, data=df, kind='count')
plt.show()

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

for i, col in enumerate(cat_cols):
    print("Unique values of column {}: {}".format(col, df[col].unique()))
# Out:
# Unique values of column cut: ['Ideal' 'Premium' 'Very Good' 'Good' 'Fair']
# Unique values of column color: ['E' 'G' 'F' 'D' 'H' 'J' 'I']
# Unique values of column clarity: ['SI1' 'IF' 'VVS2' 'VS1' 'VVS1' 'VS2' 'SI2' 'I1']

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

for i, col in enumerate(cat_cols):
    print("Unique values of column {}: {}".format(col, df[col].unique()))
    df[col] = label_encoder.fit_transform(df[col])
    print("Encoded Unique values of column {}: {}".format(col, df[col].unique()))
# Out:
# Encoded Unique values of column cut: [2 3 4 1 0]
# Encoded Unique values of column color: [1 3 2 0 4 6 5]
# Encoded Unique values of column clarity: [2 1 7 4 6 5 3 0]

# %%
#skewness and kurtosis
print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())
# Out:
# Skewness: 1.618432
# Kurtosis: 2.148840

# %%
df['log_price'] = np.log(df['price'])
print(print("Skewness: %f" % df['log_price'].skew()))
df
# Out:
# Skewness: 0.127919
# None
#        carat  cut  color  clarity  depth  table     x     y     z  price  \
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65    779
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27   5166
#
#        log_price
# 0       6.212606
# 1       6.891626
# ...

# %%
# Assuming df['price'] and df['log_price'] are columns in your DataFrame
sns.histplot(df['price'], kde=True, color='green')
plt.title('Histogram of Price')
plt.show()

sns.histplot(df['log_price'], kde=True, color='green')
plt.title('Histogram of Log-transformed Price')
plt.show()

# %%
df.dtypes
# Out:
# carat        float64
# cut            int32
# color          int32
# clarity        int32
# depth        float64
# table        float64
# x            float64
# y            float64
# z            float64
# price          int64
# log_price    float64
# dtype: object

# %%
#Outlier treatment (flooring, capping)
# taking backup before treating outliers
df_bef_OT=df.copy()
## Using User definition to return IQR, LR, UR for a column
def return_IQR_LR_UR(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=round((Q3-Q1),2)
    lower_range= round(Q1-(1.5 * IQR),2)
    upper_range= round(Q3+(1.5 * IQR),2)
    return IQR, lower_range, upper_range

# %%
# creating a function to treate outlier and cap and floor upper and lower extreme values
def Outlier_treatment(df,num_cols):   
    i=0;
    for i in df.columns:
        if (i in num_cols):
            IQR, lr, ur = return_IQR_LR_UR(df[i])
            print ('col:', i , ',lower range :', lr, ',upper range:', ur, ',No of outliers:', df[(df[i]<lr)|(df[i]>ur)][i].count(), ',outlier %:', round(df[(df[i]<lr)|(df[i]>ur)][i].count()*100/df[i].count(),2))
            df[i] =np.where(df[i]>ur,ur,df[i])
            df[i] =np.where(df[i]<lr,lr,df[i])

    return df

# %%
num_cols
# Out:
# ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
df = Outlier_treatment(df, num_cols)
# Out:
# col: carat ,lower range : -0.58 ,upper range: 2.03 ,No of outliers: 586 ,outlier %: 2.17
# col: depth ,lower range : 59.0 ,upper range: 64.6 ,No of outliers: 1417 ,outlier %: 5.26
# col: table ,lower range : 51.5 ,upper range: 63.5 ,No of outliers: 317 ,outlier %: 1.18
# col: x ,lower range : 1.95 ,upper range: 9.31 ,No of outliers: 12 ,outlier %: 0.04
# col: y ,lower range : 1.97 ,upper range: 9.29 ,No of outliers: 12 ,outlier %: 0.04
# col: z ,lower range : 1.19 ,upper range: 5.75 ,No of outliers: 14 ,outlier %: 0.05
# col: price ,lower range : -5674.5 ,upper range: 11977.5 ,No of outliers: 1778 ,outlier %: 6.6

# %%
df.shape
# Out:
# (26958, 11)

# %%
# Checking for Outliers
plt.figure(figsize= (20,20))
box_plot_no=1
sns.set(font_scale=1)
rows=calc_rows(len(num_cols), plots_in_a_row)

for col in df.columns :
    if (col in num_cols):
        box_plot_title = "Box plot of " + col
        plt.subplot(rows, plots_in_a_row, box_plot_no)
        sns.boxplot(x= col, data =df ,color='green').set(title =box_plot_title)
        box_plot_no = box_plot_no + 1

# %%
cor = df.corr().round(4)
cor
# Out:
#             carat     cut   color  clarity   depth   table       x       y  \
# carat      1.0000  0.0218  0.2917  -0.2109  0.0298  0.1873  0.9828  0.9819
# cut        0.0218  1.0000 -0.0008   0.0177 -0.1853  0.1699  0.0238  0.0294
# color      0.2917 -0.0008  1.0000  -0.0233  0.0518  0.0242  0.2742  0.2738
# clarity   -0.2109  0.0177 -0.0233   1.0000 -0.0501 -0.0808 -0.2246 -0.2216
# depth      0.0298 -0.1853  0.0518  -0.0501  1.0000 -0.2895 -0.0195 -0.0226
# table      0.1873  0.1699  0.0242  -0.0808 -0.2895  1.0000  0.1999  0.1943
# x          0.9828  0.0238  0.2742  -0.2246 -0.0195  0.1999  1.0000  0.9985
# y          0.9819  0.0294  0.2738  -0.2216 -0.0226  0.1943  0.9985  1.0000
# z          0.9808  0.0046  0.2784  -0.2280  0.0951  0.1607  0.9909  0.9905
# price      0.9367  0.0397  0.1776  -0.0729 -0.0005  0.1380  0.9134  0.9148
# log_price  0.9329  0.0224  0.1582  -0.1213  0.0050  0.1646  0.9616  0.9621
#
#                 z   price  log_price
# ...

# %%
sns.set(font_scale=1)
plt.figure(figsize=(10, 10))

sns.heatmap(data =cor, annot =True, vmax =1, vmin=-1, cmap ='coolwarm');

# %% [markdown]
# independent attributes have correlation with each other
# Thus this dataset has multicolinearity problem

# %%
num_cols
# Out:
# ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
selected_cols = np.concatenate([num_cols, [df.columns[-1]]])
sns.pairplot(df[selected_cols])

# %% [markdown]
# Skewed values in the dependent variable (target variable) can introduce several issues in statistical modeling and analysis:
#
# 1. **Biased Predictions:** especially when using models that assume a normal distribution of the target variable. Linear regression, for example, assumes normally distributed residuals, and if the target variable is highly skewed, the residuals may violate this assumption.
#
# 2. **Violated Assumptions:** Many statistical techniques, such as linear regression, assume that the residuals are normally distributed. Skewed distributions can result in non-normally distributed residuals, violating these assumptions and potentially leading to unreliable model results.
#
# 3. **Inflated Error Rates:** Skewed distributions can lead to overestimation or underestimation of errors, impacting the accuracy of the model. This can result in inflated error rates, making it challenging to assess the model's performance accurately.
#
# 4. **Impact on Significance Tests:** Skewed data can affect the results of hypothesis tests and statistical significance. If the dependent variable is not normally distributed, it may lead to inaccurate p-values and conclusions regarding the significance of predictor variables.
#
# 5. **Model Sensitivity:** Skewed distributions can make models sensitive to extreme values or outliers. This sensitivity can result in models being overly influenced by a few data points, leading to less robust and generalizable models.
#
# 6. **Difficulty in Interpretation:** Skewed data can make it challenging to interpret the relationship between the dependent variable and predictor variables accurately. It might be difficult to discern meaningful patterns or trends in the presence of skewness.
#
# 7. **Suboptimal Model Performance:** Skewed data can lead to suboptimal model performance, as models may struggle to capture the underlying patterns in the data. Transformations, such as log transformations, can help mitigate skewness and improve model performance.
#
# Using log transformation, is one way to address skewed distributions, especially if the variable has a right-skewed (positively skewed) distribution. Log transformation can help stabilize the variance and make the distribution more symmetric, making it easier for the model to capture patterns in the data.

# %%
df1 = df.copy()

# %%
X = df.iloc[:,:-2]
Y = df.iloc[:,-1]

# %%
print(X)
print(Y)
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27
#
# [26958 rows x 9 columns]
# 0        6.212606
# 1        6.891626
# 2        8.746557
# 3        6.986566
# 4        6.658011
#            ...
# 26962    8.595635
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# invoke the LinearRegression function and find the bestfit model on training data

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# R square on training data
model.score(x_train, y_train)
# Out:
# 0.9546746732331061

# %%
# on test data
r_sq = model.score(x_test, y_test)
r_sq
# Out:
# 0.955754881389558

# %%
# Let us explore the coefficients for each of the independent attributes

for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, model.coef_[idx]))
# Out:
# The coefficient for carat is -0.9105561563817461
# The coefficient for cut is 0.004958042655767223
# The coefficient for color is -0.06771627341068796
# The coefficient for clarity is 0.06350176075666332
# The coefficient for depth is 0.027355350722975784
# The coefficient for table is -0.00554095399233987
# The coefficient for x is 0.558615941692673
# The coefficient for y is 0.5504516812702762
# The coefficient for z is 0.3027040783406377

# %%
model.intercept_
# Out:
# -0.37284303717490364

# %%
df.columns[:-2]
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
df.dtypes
# Out:
# carat        float64
# cut            int32
# color          int32
# clarity        int32
# depth        float64
# table        float64
# x            float64
# y            float64
# z            float64
# price        float64
# log_price    float64
# dtype: object

# %%
for col in df.columns[:-2]:
    if df.dtypes[col] != 'int':
        sns.regplot(x=df[col], y=df['price'])
        plt.show()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluate regression performance
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 0.16024367320690824
# Mean Squared Error: 0.04522293961097439
# R-squared: 0.955754881389558

# %%
import statsmodels.api as sm

# %% [markdown]
# By default, the statsmodels library fits a line on the dataset which passes through the origin. But in order to have an intercept, you need to manually use the add_constant attribute of statsmodels. And once you’ve added the constant to your X_train dataset, you can go ahead and fit a regression line using the OLS (Ordinary Least Squares) the attribute of statsmodels as shown below,

# %%
# Add a constant to get an intercept
x_train_sm = sm.add_constant(x_train)
# Fit the resgression line using 'OLS'
model2 = sm.OLS(y_train, x_train_sm).fit()

# %%
# Print the parameters,i.e. intercept and slope of the regression line obtained
print(model2.params)
print(model2.params.shape)
col2_sta = model2.params
# Out:
# const     -0.372843
# carat     -0.910556
# cut        0.004958
# color     -0.067716
# clarity    0.063502
# depth      0.027355
# table     -0.005541
# x          0.558616
# y          0.550452
# z          0.302704
# dtype: float64
# (10,)

# %%
#Performing a summary operation lists out all different parameters of the regression line fitted
print(model2.summary()) #evaluation metrics
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              log_price   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                 4.414e+04
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):               0.00
# Time:                        09:47:41   Log-Likelihood:                 1984.0
# No. Observations:               18870   AIC:                            -3948.
# Df Residuals:                   18860   BIC:                            -3870.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3728      0.173     -2.150      0.032      -0.713      -0.033
# ...

# %%
# Add a constant to X_test
x_test_sm = sm.add_constant(x_test)
# Predict the y values corresponding to X_test_sm
y_pred = model2.predict(x_test_sm)

# %%
col2_sk = np.concatenate((model.intercept_, model.coef_), axis=None)
col2_sk
# Out:
# array([-0.37284304, -0.91055616,  0.00495804, -0.06771627,  0.06350176,
#         0.02735535, -0.00554095,  0.55861594,  0.55045168,  0.30270408])

# %%
parameters = pd.DataFrame((col2_sk, col2_sta))
parameters
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.372843 -0.910556  0.004958 -0.067716  0.063502  0.027355 -0.005541
# 1 -0.372843 -0.910556  0.004958 -0.067716  0.063502  0.027355 -0.005541
#
#           7         8         9
# 0  0.558616  0.550452  0.302704
# 1  0.558616  0.550452  0.302704

# %%
# on test data
r_sq2 = model.score(x_test, y_test)
r_sq2
# Out:
# 0.955754881389558

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# Random Forest Regressor
rfr = RandomForestRegressor(random_state=1)

# Decision Tree Regressor
dtr = DecisionTreeRegressor(random_state=1)

# %%
model.score(x_test, y_test)
# Out:
# 0.955754881389558

# %%
rfr.fit(x_train, y_train)
rfr.score(x_train, y_train)
# Out:
# 0.9987176030295608

# %%
rfr.fit(x_test, y_test)
rfr.score(x_test, y_test)
# Out:
# 0.9983919846327315

# %%
dtr.fit(x_train, y_train)
dtr.score(x_train, y_train)
# Out:
# 0.9999954081232757

# %%
dtr.fit(x_test, y_test)
dtr.score(x_test, y_test)
# Out:
# 0.9999989241616589

# %%
y_pred_dtr = dtr.predict(x_test)
y_pred_rfr = rfr.predict(x_test)
y_pred_lr = model.predict(x_test)

# %%
fig, ax = plt.subplots(1,1, sharey=False,figsize= (25,15))
ax.scatter(y_test, y_pred_dtr, color='Red',label='Decision Tree Regression')
ax.scatter(y_test, y_pred_rfr, color='Green',label='Random Forest Regression')
ax.scatter(y_test, y_pred_lr, color='Yellow',label='Logistic Regression')
plt.show()
